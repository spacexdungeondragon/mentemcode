# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

stocks = pd.read_excel('stock_index.xlsx')

# %% [markdown]
# ## Exercise 1: Scatter Plots

# %%
plt.scatter(stocks['NIKKEI'], stocks['SP'])
plt.title('Relationship between NIKKEI and SP')
plt.xlabel('NIKKEI')
plt.ylabel('SP')

plt.show()

# %% [markdown]
# ## Exercise 2
#
# Exercise 2: Correlation matrix heatmap
#
# Create a correlation matrix heatmap for the entire 'stocks' data frame.
# Change the colour scheme of the heatmap using the parameter cmap='coolwarm'.
# Analyse the heatmap and identify which three indicies have the highest correlations.

# %%
corr_matrix = stocks.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# ### Rank top correlations

# %%
def top_correlations(dataframe, count):
    # sort in descending order
    sorted = corr_matrix.unstack().sort_values(ascending=False)
    # remove duplicates and comparisons with self
    top_correlations = sorted.loc[lambda x : x!=1].drop_duplicates().head(count)
    print(f'Top {count} correlations\n')
    for x in range(count):
        xlabel, ylabel = top_correlations.index[x][0], top_correlations.index[x][1]
        rank = x + 1
        # format output
        print(f"{x + 1: <2} {xlabel : <6} {'x' : <3} {ylabel : <6} {top_correlations[x] : ^10}") 

top_correlations(stocks, 3)
# Out:
# Top 3 correlations
#
# 1  FTSE   x   EU     0.9489633564473225
# 2  EU     x   DAX    0.9363930499593206
# 3  FTSE   x   DAX    0.8673693480233561
# C:\Users\willj\AppData\Local\Temp\ipykernel_36548\643356116.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f"{x + 1: <2} {xlabel : <6} {'x' : <3} {ylabel : <6} {top_correlations[x] : ^10}")
