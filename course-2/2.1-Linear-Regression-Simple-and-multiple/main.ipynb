# %% [markdown]
# Here are the steps for the activity:
#
# 1. Run the initial code: Execute the given Python code to visualise the initial dataset and the fitted regression line.
#
#     You have the following data:
#
#     `X : [2, 4, 6]`
#
#     `Y : [4, 7, 9]`

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Sample data
X = np.array([2, 4, 6]).reshape(-1, 1)
Y = np.array([4, 7, 9])

# Create a linear regression model
model = LinearRegression()
model.fit(X, Y)

# Make predictions
Y_pred = model.predict(X)

# Coefficients
beta_0 = model.intercept_
beta_1 = model.coef_[0]

# Plot the data and the regression line

plt.scatter(X, Y, color='blue', label='Actual data')
plt.plot(X, Y_pred, color='red', label='Regression line')
plt.title(f"Y = {beta_1:.2f}*X+{beta_0:.2f}")
plt.xlabel('Independent Variable (X)')
plt.ylabel('Dependent Variable (Y)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 2. Modify the sample data: change the values of the arrays `X` and `Y` to create a new dataset. Add or remove data points as needed. For example, you can increase the number of data points or introduce outliers.
#
# 3. Re-run the code: execute the modified code to see how the changes in the sample data affect the regression line. Take note of any shifts or variations in the line.
#
# 4. Observe and analyse: reflect on the observations and analyse how alterations in the sample data impact the linear regression model.
#
# Consider questions such as: How do outliers affect the line? What happens when data points are closer together or more spread out?
