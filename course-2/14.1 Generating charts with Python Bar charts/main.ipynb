# %%
import matplotlib.pyplot as plt
 
# Banking products and their adjusted annual growth rates
products = ['Savings', 'Loans', 'Investments', 'Credit Cards', 'Mortgages']
adjusted_growth_rates = ________  # Adjusted growth rates in percentage
 
# Adjusting colors for better contrast
colors = ________
 
plt.bar(products, adjusted_growth_rates, color=colors)  # Creating a bar chart with adjusted growth rates and colours
 
plt.xlabel("________")  # Setting x-label as 'Banking Products'
plt.ylabel("________")  # Setting y-label as 'Adjusted Annual Growth Rate (%)'
plt.title("________")  # Setting the chart title
# Out:
# Text(0.5, 1.0, 'Adjusted Annual Growth Rate of Banking Products')

# %% [markdown]
# Alt text: Customised vertical bar chart showing adjusted annual growth rate of banking products.
#
# Return to the course to complete the knowledge check for this lesson.
